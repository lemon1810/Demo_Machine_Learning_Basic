# %% [markdown]
# #Bài 1

# %% [markdown]
# #Khai báo:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Khai báo:

# %%
# %matplotlib inline

# %% [markdown]
# #Code

# %%
x = 2 * np.random.rand(100,1)
y = 4 + 3*X + np.random.randn(100,1)
x_b = np.c_[np.ones((100, 1)), X]
print (x,y)


plt.plot(x,y,'b.')

plt.show()
# Out:
# [[1.56803386]
#  [1.59768275]
#  [0.76593102]
#  [0.05121564]
#  [0.29979117]
#  [1.53711688]
#  [0.33164781]
#  [1.70489141]
#  [1.60092698]
#  [0.73129829]
#  [0.09663561]
#  [1.1398676 ]
#  [1.84495044]
#  [1.91362189]
#  [1.7289433 ]
#  [1.67012739]
#  [0.85596419]
#  [0.38456092]
#  [0.59940613]
#  [0.15373176]
#  [1.45076177]
#  [1.77414022]
#  [1.81127625]
#  [1.7026072 ]
#  [0.77442916]
#  [1.13397813]
#  [0.00211898]
#  [0.28714915]
#  [1.52494137]
#  [1.04061171]
#  [0.76623561]
#  [0.67646079]
#  [1.12779808]
#  [1.19883047]
#  [1.44190404]
#  [1.3565487 ]
#  [1.44315769]
#  [1.48261316]
#  [1.95918326]
#  [1.16262415]
#  [1.24494273]
#  [1.17370922]
#  [0.79506626]
#  [1.95262174]
#  [1.44511695]
#  [0.76731702]
#  [1.87763904]
#  [0.72803682]
#  [1.35933397]
#  [1.03563731]
#  [1.18924129]
#  [1.16725045]
#  [1.08911379]
#  [0.10572021]
#  [0.1821909 ]
#  [1.0188618 ]
#  [1.75721892]
#  [1.36236962]
#  [1.46684304]
#  [0.33104741]
#  [1.44110676]
#  [0.20899608]
#  [1.32232093]
#  [1.1642303 ]
#  [0.80639399]
#  [0.42168903]
#  [1.1755402 ]
#  [1.51640508]
#  [0.58588438]
#  [1.81761061]
#  [0.6585025 ]
#  [1.04254229]
#  [1.94742091]
#  [1.38475662]
#  [0.92029949]
#  [1.29631286]
#  [1.45313223]
#  [1.9113469 ]
#  [0.0916238 ]
#  [0.30144952]
#  [1.50156771]
#  [1.94575925]
#  [0.03771868]
#  [1.40033345]
#  [0.96199775]
#  [1.17897209]
#  [1.95322903]
#  [1.60144149]
#  [1.33725246]
#  [0.4603807 ]
#  [1.56756037]
#  [0.02144378]
#  [1.21843477]
#  [0.59240112]
#  [0.67706002]
#  [1.14951888]
#  [0.56601499]
#  [0.41277632]
#  [0.28309019]
#  [0.17663537]] [[ 7.90887108]
#  [ 9.14475133]
#  [ 4.22890033]
#  [ 8.00521913]
#  [ 9.19036767]
#  [ 5.50002411]
#  [ 5.32442494]
#  [ 6.74969833]
#  [ 7.1830614 ]
#  [ 5.09679258]
#  [ 5.97970468]
#  [ 7.62884014]
#  [ 7.89273308]
#  [ 8.1457976 ]
#  [ 8.6214827 ]
#  [ 5.59335314]
#  [ 6.27471757]
#  [ 4.62846205]
#  [ 3.73468282]
#  [ 5.90343107]
#  [ 5.15237306]
#  [ 7.56051077]
#  [ 8.7718195 ]
#  [ 7.26194008]
#  [ 7.70947573]
#  [ 4.6960562 ]
#  [ 8.7062593 ]
#  [ 6.70992784]
#  [ 5.31282617]
#  [ 6.57094944]
#  [ 8.9573419 ]
#  [ 8.64072796]
#  [10.65254599]
#  [ 5.19490056]
#  [ 5.67310827]
#  [ 3.94375921]
#  [ 9.58613759]
#  [ 7.6071426 ]
#  [ 5.19960705]
#  [ 4.77442377]
#  [ 5.99287934]
#  [ 9.22013232]
#  [ 3.95761001]
#  [ 3.82196573]
#  [ 8.17988977]
#  [ 6.7248631 ]
#  [ 7.68002051]
#  [ 7.07338152]
#  [ 6.65692401]
#  [ 4.1623417 ]
#  [ 4.3727957 ]
#  [ 7.37144071]
#  [ 7.73880055]
#  [ 5.26299251]
#  [ 5.44542693]
#  [ 8.17248548]
#  [ 8.74195033]
#  [ 3.56446835]
#  [ 8.68977488]
#  [ 6.26442512]
#  [ 6.66303221]
#  [ 5.5433728 ]
#  [ 4.70510992]
#  [ 5.54043091]
#  [ 5.46010907]
#  [ 5.27144088]
#  [ 6.72401533]
#  [ 7.63575745]
#  [ 6.68656437]
#  [ 6.16381986]
#  [ 5.89462729]
#  [ 3.20384377]
#  [ 7.91804137]
#  [ 4.68503907]
#  [11.03869901]
#  [ 4.4683533 ]
#  [ 4.67306904]
#  [ 7.40458116]
#  [ 9.75033941]
#  [ 9.63002206]
#  [ 7.01052436]
#  [ 6.18632898]
#  [ 8.71604253]
#  [ 7.68879381]
#  [ 8.20899591]
#  [11.09989815]
#  [ 8.33556115]
#  [ 9.30171994]
#  [ 6.23463686]
#  [ 5.13528159]
#  [ 5.39951695]
#  [ 1.93149084]
#  [10.28711866]
#  [ 5.3528125 ]
#  [ 8.27453412]
#  [ 5.46187736]
#  [10.03932946]
#  [ 5.80586619]
#  [ 9.25484372]
#  [ 6.5984791 ]]

# %% [markdown]
# #Bài 2
# #Code2:

# %%
X = 2 * np.random.rand(100,1)
y = 4 + 3*X + np.random.randn(100,1)
x_b = np.c_[np.ones((100, 1)), X]
plt.plot(x,y,'b.')
print(x_b.shape)
print(y.shape)
plt.show()
# Out:
# (100, 2)
# (100, 1)

# %% [markdown]
# #Bài 3:

# %%
x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2, 1)), x_new]
param = np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y) # ( (x)T * x)^-1

print (param)
# Out:
# [[3.80938171]
#  [3.1277181 ]]

# %% [markdown]
# #Bài 4:

# %%
x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2, 1)), x_new]
y_pred=x_new_b.dot(param)
print(y_pred)
# Out:
# [[ 3.80938171]
#  [10.06481791]]

# %% [markdown]
# #Bài 5:

# %%
plt.plot(x,y,"b.")
plt.plot(x_new,y_pred,"r-")
